# %% [markdown]
# # Texto

# %%
a = 5
b = 10

# %%
a + b
# Out:
# 15

# %%
a - b
# Out:
# -5

# %%
c = 2.2

# %%
a + c
# Out:
# 7.2

# %%
a / b # divisão
# Out:
# 0.5

# %%
a * b # multiplicação
# Out:
# 50

# %%
a**2 # exponenciação
# Out:
# 25

# %%
import math
math.sqrt(9) # raiz quadrada de 9
# Out:
# 3.0

# %%
9**(1/2)
# Out:
# 3.0

# %% [markdown]
# # Operações com strings

# %%
saudacao = "oi"
nome = "fernando"

# %%
# Concatenar strings
saudacao + " " + nome
# Out:
# 'oi fernando'

# %% [markdown]
# # Type casting

# %%
# Type casting (modificar tipo dos objetos)
c = 2.2
b = 10

# %%
int(c) # Modifica para inteiro
# Out:
# 2

# %%
str(c) # Modifica para string
# Out:
# '2.2'

# %%
float(b) # Modifica para float
# Out:
# 10.0

# %% [markdown]
# # Exercícios

# %% [markdown]
# ### Exercício 1

# %%
var1 = 6
var2 = 2

# %%
var3 = var1 / var2
print(var3)
type(var3)
# Out:
# 3.0
# float

# %% [markdown]
# ### Exercício 2

# %%
faturamento = 8000 * 12
amigo1 = faturamento * 0.3
amigo2 = faturamento - amigo1

print(faturamento)
print(amigo1)
print(amigo2)
# Out:
# 96000
# 28800.0
# 67200.0

# %% [markdown]
# ### Exercício 3

# %%
5 + 3 * 10 / 3 == 15
# Out:
# True

# %% [markdown]
# ### Exercício 4

# %%
movieName = "The Shining"
actors = ["Jack Nicholson", "Shelley Duval", "Danny Lloyd", "scatman Crothers", "Barry Nelson"]
scores = [4.5, 4.0, 5.0]
comments = ["Best Horror Film I Have Ever Seen", "A truly brilliant and scary film from Stanley Kubrick", "A masterpiece of psychological horror"]

# %%
# resposta 1
lista1 = [movieName, actors, scores, comments]

lista1
# Out:
# ['The Shining',
#  ['Jack Nicholson',
#   'Shelley Duval',
#   'Danny Lloyd',
#   'scatman Crothers',
#   'Barry Nelson'],
#  [4.5, 4.0, 5.0],
#  ['Best Horror Film I Have Ever Seen',
#   'A truly brilliant and scary film from Stanley Kubrick',
#   'A masterpiece of psychological horror']]

# %%
# resposta 2
lista1[1][0]
# Out:
# 'Jack Nicholson'

# %%
# resposta 3
max(lista1[2])
# Out:
# 5.0

# %%
indice = lista1[2].index(max(lista1[2]))
indice
# Out:
# 2

# %%
lista1[3][indice]
# Out:
# 'A masterpiece of psychological horror'

# %% [markdown]
# ### Exercício 5

# %%
idade = input("Qual é a sua idade?")
# Out:
# Qual é a sua idade?28

# %%
idade
# Out:
# '28'

# %%
type(idade)
# Out:
# str

# %%
float(idade)
# Out:
# 28.0
